# %% [markdown]
# # Computer Vision Experiments Template
#
# This notebook serves as a template for computer vision experiments. It includes essential setup, utilities, and workflow components commonly used in computer vision research and development.
#
# ## Table of Contents
# 1. [Import Required Libraries](#import-libraries)
# 2. [Set Up Configuration and Constants](#configuration)
#
# ---

# %% [markdown]
# ## 1. Import Required Libraries {#import-libraries}
#
# Import essential libraries for computer vision including OpenCV, PIL, matplotlib, numpy, pandas, and deep learning frameworks.

# %%
# Core libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import os
import warnings
warnings.filterwarnings('ignore')

# Image processing libraries
import cv2
from PIL import Image, ImageEnhance
from skimage import io, transform, filters, measure
from skimage.feature import hog, local_binary_pattern
from skimage.color import rgb2gray, gray2rgb

# Deep learning frameworks (choose one or both based on your preference)
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset

# Alternative: TensorFlow/Keras
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras import layers

# Evaluation and metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# Visualization
import plotly.express as px
import plotly.graph_objects as go
from matplotlib.patches import Rectangle

# Set random seeds for reproducibility
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)

print("All libraries imported successfully!")
print(f"OpenCV version: {cv2.__version__}")
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
# Out:
# All libraries imported successfully!
# OpenCV version: 4.12.0
# PyTorch version: 2.8.0+cu126
# CUDA available: True

# %% [markdown]
# ## 2. Set Up Configuration and Constants {#configuration}
#
# Define configuration parameters, file paths, model hyperparameters, and other constants that will be used throughout the experiment.

# %%
# Configuration class to organize all parameters
class Config:
    # Data paths
    DATA_DIR = Path("../Data")
    IMAGES_DIR = DATA_DIR / "images"
    LABELS_DIR = DATA_DIR / "labels"
    OUTPUT_DIR = Path("./outputs")
    MODELS_DIR = Path("./models")
    
    # Create directories if they don't exist
    OUTPUT_DIR.mkdir(exist_ok=True)
    MODELS_DIR.mkdir(exist_ok=True)
    
    # Image parameters
    IMAGE_SIZE = (224, 224)  # Standard size for many pre-trained models
    CHANNELS = 3  # RGB images
    BATCH_SIZE = 32
    
    # Training parameters
    LEARNING_RATE = 0.001
    EPOCHS = 50
    VALIDATION_SPLIT = 0.2
    TEST_SPLIT = 0.1
    
    # Model parameters
    NUM_CLASSES = 10  # Update based on your dataset
    DROPOUT_RATE = 0.5
    
    # Device configuration
    DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    # Visualization parameters
    FIGSIZE = (12, 8)
    DPI = 100

# Initialize configuration
config = Config()

print(f"Configuration initialized!")
print(f"Device: {config.DEVICE}")
print(f"Data directory: {config.DATA_DIR}")
print(f"Image size: {config.IMAGE_SIZE}")
print(f"Batch size: {config.BATCH_SIZE}")
# Out:
# Configuration initialized!
# Device: cuda
# Data directory: ..\Data
# Image size: (224, 224)
# Batch size: 32
